# %%
from numpy import genfromtxt

# %%
cd "C:/Users/Marissa/Documents/Portfolio/TaylorSwift/DataSet/"
# Out:
# C:\Users\Marissa\Documents\Portfolio\TaylorSwift\DataSet

# %%
train_X = genfromtxt('./X_train_public.csv', delimiter=",")
train_Y = genfromtxt('./Y_train_public.csv', delimiter=",")

# %%
print train_X.shape
print train_Y.shape
# Out:
# (15680L, 3333L)
# (15680L,)

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(train_X, train_Y, test_size=0.3)
print X_train.shape
print Y_train.shape
print X_test.shape
print Y_test.shape
# Out:
# (10976L, 3333L)
# (10976L,)
# (4704L, 3333L)
# (4704L,)

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5,10.5)
plot(X_train[500,:])

# %%
kspace = np.fft.fft(X_train)
kspace = np.fft.fftshift(kspace)
k_test = np.fft.fft(X_test)
k_test = np.fft.fftshift(k_test)

# %%
kspace.shape
# Out:
# (10976L, 3333L)

# %%
fig2 = matplotlib.pyplot.gcf()
fig2.set_size_inches(18.5,10.5)
plot(kspace[500],'r', kspace[20], 'b' )
# Out:
# [<matplotlib.lines.Line2D at 0x2f4359e8>,
#  <matplotlib.lines.Line2D at 0x2f435c18>]

# %%
good = mean(kspace[Y_train == 1,:])
good_train = Y_train == 1
bad_train = Y_train == 0

# Lets see if we can find subclusters
from sklearn.cluster import Ward
groupsModel = Ward(4)
good_cluster = groupsModel.fit_predict(kspace[good_train])

# %%
unique(good_cluster)
numpy.bincount(good_cluster)
# Out:
# array([4994,  154,  239,  117], dtype=int64)

# %% [markdown]
# Looks like hierarchical clustering is not working

# %% [markdown]
# ### Create the training and test feature sets

# %%
Combined = numpy.concatenate((X_train, kspace), axis = 1)
C_test = numpy.concatenate((X_test, k_test), axis = 1)
Combined.shape
# Out:
# (10976L, 6666L)

# %% [markdown]
# ## Fitting the model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=10, verbose=True,max_depth=None,min_samples_split=1, random_state=0)

# %% [markdown]
# ###Combined data

# %%
model.fit(Combined,Y_train)
# Out:
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:   26.2s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   26.2s finished
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             min_density=None, min_samples_leaf=1, min_samples_split=1,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=0,
#             verbose=True)

# %%
Y_test_pred = model.predict(C_test)
# Out:
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %%
my_score = model.score(C_test,Y_test)
print my_score
# Out:
# 0.702380952381
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %%
confusion_matrix(Y_test, Y_test_pred)
# Out:
# array([[1563,  749],
#        [ 409, 1983]])

# %% [markdown]
# ###Time only

# %%
model.fit(Combined,Y_train)
